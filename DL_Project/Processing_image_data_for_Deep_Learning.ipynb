# %% [markdown]
# <a href="https://colab.research.google.com/github/atikhasan007/DeepLearning/blob/main/DL_Project/Processing_image_data_for_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Topic**
# - Reading an image file and converting it to a numpy array
# - Resizing an image
# - RGB to Grayscale conversion

# %%
# getting an image using web get
# !wget 'https://vitapet.com/media/nmqdmem5/signs-of-a-healthy-dog-470x300.jpg'
# Out:
# --2026-04-10 09:38:10--  https://vitapet.com/media/nmqdmem5/signs-of-a-healthy-dog-470x300.jpg
# Resolving vitapet.com (vitapet.com)... 104.18.10.20, 104.18.11.20, 2606:4700::6812:b14, ...
# Connecting to vitapet.com (vitapet.com)|104.18.10.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34032 (33K) [image/jpeg]
# Saving to: ‘signs-of-a-healthy-dog-470x300.jpg’
#
# signs-of-a-healthy- 100%[===================>]  33.23K  --.-KB/s    in 0.003s
#
# 2026-04-10 09:38:11 (12.1 MB/s) - ‘signs-of-a-healthy-dog-470x300.jpg’ saved [34032/34032]

# %% [markdown]
# **Libraries that can be used for image processing**
# - matplotlib.image
# - pillow
# - OpenCV (cv2)

# %%
# importing the image module form matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mpimg.imread('/content/dog.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (300, 470, 3)

# %%
print(img)
# Out:
# [[[  4  12   1]
#   [  4  12   1]
#   [  4  12   1]
#   ...
#   [ 31  46   3]
#   [ 35  49   0]
#   [ 34  45   2]]
#
#  [[  4  12   1]
#   [  4  12   1]
#   [  4  12   1]
#   ...
#   [ 31  46   3]
#   [ 35  49   0]
#   [ 34  45   2]]
#
#  [[  4  12   1]
#   [  4  12   1]
#   [  4  12   1]
#   ...
#   [ 31  46   3]
#   [ 35  49   0]
#   [ 34  45   2]]
#
#  ...
#
#  [[126 130  53]
#   [138 136  62]
#   [109 107  20]
#   ...
#   [ 89 129   0]
#   [ 89 130   2]
#   [ 93 130   0]]
#
#  [[117 124  56]
#   [123 124  56]
#   [ 91  93  10]
#   ...
#   [ 75 116   0]
#   [ 65 107   0]
#   [ 93 131  20]]
#
#  [[134 145  66]
#   [127 135  52]
#   [ 90  99   6]
#   ...
#   [ 85 123   0]
#   [ 77 115   0]
#   [ 97 130  25]]]

# %%
# displaying the image from  numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# **Resizing the image using Pillow Library**

# %%
from PIL import Image
img = Image.open('/content/dog.jpg')
img_resized = img.resize((200,200))
img_resized
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res = mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot = plt.imshow(img)
plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to GrayScale image using OpenCV**

# %%
# importing OpenCV Library
import cv2

# %%
img = cv2.imread("/content/dog.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 470, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
grayscale_image
# Out:
# array([[  8,   8,   8, ...,  31,  33,  31],
#        [  8,   8,   8, ...,  31,  33,  31],
#        [  8,   8,   8, ...,  31,  33,  31],
#        ...,
#        [107, 114,  81, ...,  86,  87,  87],
#        [103, 104,  68, ...,  77,  70,  93],
#        [120, 109,  70, ...,  82,  76,  95]], dtype=uint8)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (300, 470)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in google colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
# display the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=470x300>

# %%
 # saving the grayscale image
 cv2.imwrite('dog_grayscale_image.jpg' , grayscale_image)
# Out:
# True
